# %% [markdown]
# <a href="https://colab.research.google.com/github/ldenarbonne/MLOpengouins/blob/1_productionizing_ML/bitcoin_price_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# frequency distribution of log returns
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib import pyplot as plt
from scipy import stats
from scipy.stats import norm
from scipy.stats import skew, kurtosis
import seaborn as sns
from seaborn import histplot


plt.figure(figsize=(10,5))
sns.histplot(df['Log_Returns'].dropna(), bins=100, kde=True,
                color='purple')
plt.title('Frequency Distribution of Bitcoin Log Returns')
plt.xlabel('Log Returns')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3213849403.py in <cell line: 0>()
#      10
#      11 plt.figure(figsize=(10,5))
# ---> 12 sns.histplot(df['Log_Returns'].dropna(), bins=100, kde=True,
#      13                 color='purple')
#      14 plt.title('Frequency Distribution of Bitcoin Log Returns')
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("/home/laure/code/bitcoin_prediction_model/data/btcusd_1-min_data - 10000.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2681225053.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/home/laure/code/bitcoin_prediction_model/data/btcusd_1-min_data - 10000.csv")
#
# ...

# %%
##Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
